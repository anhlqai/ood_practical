# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MQ-solutions/ood_practical/RTL/CIFAR/CIFAR/data
# !ls .
# Out:
# /content/drive/MyDrive/MQ-solutions/ood_practical/RTL/CIFAR/CIFAR/data

# %%
# !wget http://ufldl.stanford.edu/housenumbers/test_32x32.mat
# !wget https://data.csail.mit.edu/places/places365/test_256.tar
# Out:
# --2025-03-15 07:20:55--  http://ufldl.stanford.edu/housenumbers/test_32x32.mat
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64275384 (61M) [text/plain]
# Saving to: ‘test_32x32.mat’
#
# test_32x32.mat      100%[===================>]  61.30M  2.45MB/s    in 34s
#
# 2025-03-15 07:21:29 (1.80 MB/s) - ‘test_32x32.mat’ saved [64275384/64275384]
#
# --2025-03-15 07:21:29--  https://data.csail.mit.edu/places/places365/test_256.tar
# Resolving data.csail.mit.edu (data.csail.mit.edu)... 128.52.131.233
# Connecting to data.csail.mit.edu (data.csail.mit.edu)|128.52.131.233|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4736829440 (4.4G) [application/x-tar]
# Saving to: ‘test_256.tar’
#
# test_256.tar        100%[===================>]   4.41G  49.3MB/s    in 1m 58s
#
# ...

# %%
# !tar -xvf dtd-r1.0.1.tar.gz
# !tar -xvf iSUN.tar.gz
# !tar -xvf LSUN_resize.tar.gz
# !tar -xvf LSUN.tar.gz
# !tar -xvf test_256.tar
# Out:
# Streaming output truncated to the last 5000 lines.
# test_256/Places365_test_00250096.jpg
# test_256/Places365_test_00065648.jpg
# test_256/Places365_test_00114887.jpg
# test_256/Places365_test_00292147.jpg
# test_256/Places365_test_00167457.jpg
# test_256/Places365_test_00279518.jpg
# test_256/Places365_test_00223034.jpg
# test_256/Places365_test_00167825.jpg
# test_256/Places365_test_00159480.jpg
# test_256/Places365_test_00072311.jpg
# test_256/Places365_test_00203524.jpg
# test_256/Places365_test_00259008.jpg
# test_256/Places365_test_00185096.jpg
# test_256/Places365_test_00147147.jpg
# test_256/Places365_test_00203956.jpg
# test_256/Places365_test_00045358.jpg
# test_256/Places365_test_00270586.jpg
# test_256/Places365_test_00087289.jpg
# test_256/Places365_test_00231233.jpg
# test_256/Places365_test_00175650.jpg
# test_256/Places365_test_00280340.jpg
# test_256/Places365_test_00242291.jpg
# test_256/Places365_test_00304065.jpg
# test_256/Places365_test_00040874.jpg
# ...

# %%
# %cd /content/drive/MyDrive/MQ-solutions/ood_practical/RTL/CIFAR/CIFAR
# !python RTL.py
# Out:
# /content/drive/MyDrive/MQ-solutions/ood_practical/RTL/CIFAR/CIFAR
# manual seed: 1
# {'ood_score': None, 'embed': <function RTL_OOD.initial_embed.<locals>.<lambda> at 0x7b7b5e30a160>, 'norm': <function RTL_OOD.initial_norm.<locals>.<lambda> at 0x7b7a9b946fc0>, 'gamma_in': <bound method RTL_OOD.gamma_residual of <__main__.RTL_OOD object at 0x7b7a9c7fa890>>}
# ...

# %%
# !python RTL_plus.py
